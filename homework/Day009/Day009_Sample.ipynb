# %% [markdown]
# # 範例
#
# 以正確的副檔名下載網頁中的圖片
# 範例網頁:https://www.ptt.cc/bbs/Beauty/M.1574854555.A.E5C.html
#
# Note：因為 PTT 會詢問「是否滿 18 歲」，這邊可以用 cookies 繞過
#
# `requests.get(URL, cookies={'over18': '1'}`

# %%
import requests
import os

from bs4 import BeautifulSoup
from PIL import Image

# %%
url = 'https://www.ptt.cc/bbs/Beauty/M.1574854555.A.E5C.html'
resp = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(resp.text)
print(soup.prettify())
# Out:
# an>
#      <span class="f3 hl push-userid">
#       wisey
#      </span>
#      <span class="f3 push-content">
#       : 靛好帥呀
#      </span>
#      <span class="push-ipdatetime">
#       223.137.203.248 11/28 00:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       airplanes
#      </span>
#      <span class="f3 push-content">
#       : 我還是忠於我的偶像木村
#      </span>
#      <span class="push-ipdatetime">
#       36.229.196.247 11/28 00:17
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hard9977
#      </span>
#      <span class="f3 push-content">
#       : 稻葉55歲碾壓各世代
#      </span>
#      <span class="push-ipdatetime">
#       1.200.195.207 11/28 00:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hcrcool
#      </span>
#      <span class="f3 push-content">
#       : 沒有Hyde耶..
#      </span>
#      <span class="push-ipdatetime">
#       36.234.197.186 11/28 00:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       chalon
#      </span>
#      <span class="f3 push-content">
#       : 藤岡靛在夏洛克裡面超帥
#      </span>
#      <span class="push-ipdatetime">
#       111.243.2.21 11/28 00:35
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sck3612575
#      </span>
#      <span class="f3 push-content">
#       : 佐藤健超帥==
#      </span>
#      <span class="push-ipdatetime">
#       111.249.21.100 11/28 00:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       rm76
#      </span>
#      <span class="f3 push-content">
#       : 稻葉最高！！！
#      </span>
#      <span class="push-ipdatetime">
#       110.28.225.192 11/28 00:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       freecurve
#      </span>
#      <span class="f3 push-content">
#       : 真的無法了解齋藤工
#      </span>
#      <span class="push-ipdatetime">
#       61.70.99.230 11/28 00:43
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       larryla21
#      </span>
#      <span class="f3 push-content">
#       : 怎麼覺得第一名好像胡歌
#      </span>
#      <span class="push-ipdatetime">
#       101.12.70.126 11/28 00:57
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       lookyour
#      </span>
#      <span class="f3 push-content">
#       : 為什麼第一名那麼像長頭髮的大根...
#      </span>
#      <span class="push-ipdatetime">
#       27.246.96.187 11/28 01:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       chrisli7
#      </span>
#      <span class="f3 push-content">
#       : 第七好帥
#      </span>
#      <span class="push-ipdatetime">
#       223.137.171.194 11/28 01:09
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       candn
#      </span>
#      <span class="f3 push-content">
#       : 福山雅治！算了還有妻木夫聰
#      </span>
#      <span class="push-ipdatetime">
#       114.137.4.142 11/28 01:37
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ijoj
#      </span>
#      <span class="f3 push-content">
#       : 怎麼沒山下智久
#      </span>
#      <span class="push-ipdatetime">
#       175.96.76.104 11/28 01:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       tp6rmp4jo3ya
#      </span>
#      <span class="f3 push-content">
#       : 山下智久
#      </span>
#      <span class="push-ipdatetime">
#       125.230.2.84 11/28 02:10
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       hotecyan
#      </span>
#      <span class="f3 push-content">
#       : 阿部寬超帥！！
#      </span>
#      <span class="push-ipdatetime">
#       122.121.127.126 11/28 02:27
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Tsubasa1008
#      </span>
#      <span class="f3 push-content">
#       : 2.7帥
#      </span>
#      <span class="push-ipdatetime">
#       111.242.0.151 11/28 02:58
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Scubadive
#      </span>
#      <span class="f3 push-content">
#       : 居然沒東尼大木
#      </span>
#      <span class="push-ipdatetime">
#       180.217.216.98 11/28 03:08
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       flyboring
#      </span>
#      <span class="f3 push-content">
#       : 男生投給西島秀俊
#      </span>
#      <span class="push-ipdatetime">
#       184.67.100.82 11/28 04:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       drittenapril
#      </span>
#      <span class="f3 push-content">
#       : Dean真的帥啊
#      </span>
#      <span class="push-ipdatetime">
#       114.136.228.183 11/28 05:11
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mmchen
#      </span>
#      <span class="f3 push-content">
#       : 居然沒木村
#      </span>
#      <span class="push-ipdatetime">
#       111.185.154.29 11/28 06:58
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       HarunaOno
#      </span>
#      <span class="f3 push-content">
#       : 也沒有生田斗真
#      </span>
#      <span class="push-ipdatetime">
#       42.77.135.17 11/28 07:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       plsmaop
#      </span>
#      <span class="f3 push-content">
#       : 福士蒼汰跟竹內涼真差在哪
#      </span>
#      <span class="push-ipdatetime">
#       36.231.105.220 11/28 07:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mecheers
#      </span>
#      <span class="f3 push-content">
#       : 真劍佑沒上，這名單沒說服力
#      </span>
#      <span class="push-ipdatetime">
#       69.206.246.194 11/28 07:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       w26236196
#      </span>
#      <span class="f3 push-content">
#       : 羅蘭杜!!!
#      </span>
#      <span class="push-ipdatetime">
#       211.72.32.19 11/28 08:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       tt7642
#      </span>
#      <span class="f3 push-content">
#       : 第一名...果然台日審美觀不同
#      </span>
#      <span class="push-ipdatetime">
#       111.252.229.99 11/28 08:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       CMPunk
#      </span>
#      <span class="f3 push-content">
#       : 我一直覺得藤岡靛紅回去蠻猛的
#      </span>
#      <span class="push-ipdatetime">
#       39.13.97.165 11/28 09:01
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       klm7529517
#      </span>
#      <span class="f3 push-content">
#       : 怎沒有森林原人
#      </span>
#      <span class="push-ipdatetime">
#       27.242.104.41 11/28 09:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       abellea85209
#      </span>
#      <span class="f3 push-content">
#       : 沒阿部寬...
#      </span>
#      <span class="push-ipdatetime">
#       220.136.114.77 11/28 09:58
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       ben1357956
#      </span>
#      <span class="f3 push-content">
#       : 小栗旬呢？！ 第一名誰阿
#      </span>
#      <span class="push-ipdatetime">
#       210.240.248.234 11/28 10:33
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       ericchien
#      </span>
#      <span class="f3 push-content">
#       : 第一名這...
#      </span>
#      <span class="push-ipdatetime">
#       203.74.123.241 11/28 10:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       mingdao
#      </span>
#      <span class="f3 push-content">
#       : 幾乎都是繩文人吧
#      </span>
#      <span class="push-ipdatetime">
#       61.221.54.101 11/28 10:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       issemn
#      </span>
#      <span class="f3 push-content">
#       : 我只服大谷翔平
#      </span>
#      <span class="push-ipdatetime">
#       111.242.191.112 11/28 10:59
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fongminp
#      </span>
#      <span class="f3 push-content">
#       : 小朋友還認識稻葉啊，頗意外
#      </span>
#      <span class="push-ipdatetime">
#       49.216.9.114 11/28 12:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       kiki1235678g
#      </span>
#      <span class="f3 push-content">
#       : No1很像牛郎店紅牌
#      </span>
#      <span class="push-ipdatetime">
#       110.26.96.106 11/28 14:54
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       aegisWIsL
#      </span>
#      <span class="f3 push-content">
#       : 稻葉全稱霸也太猛
#      </span>
#      <span class="push-ipdatetime">
#       119.14.43.152 11/28 15:05
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       fredcandy
#      </span>
#      <span class="f3 push-content">
#       : B’z讚啦！
#      </span>
#      <span class="push-ipdatetime">
#       101.12.65.253 11/28 15:09
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       lewis40912
#      </span>
#      <span class="f3 push-content">
#       : 阿部寬
#      </span>
#      <span class="push-ipdatetime">
#       27.242.12.87 11/28 15:18
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       coco100
#      </span>
#      <span class="f3 push-content">
#       : 居然沒有山下智久
#      </span>
#      <span class="push-ipdatetime">
#       114.46.46.182 11/28 15:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       telescopy
#      </span>
#      <span class="f3 push-content">
#       : 沒想到稲葉這麼受歡迎！？
#      </span>
#      <span class="push-ipdatetime">
#       110.28.227.54 11/28 16:29
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sing60905
#      </span>
#      <span class="f3 push-content">
#       : 木村過氣了嗎
#      </span>
#      <span class="push-ipdatetime">
#       223.137.249.197 11/28 16:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       seishin
#      </span>
#      <span class="f3 push-content">
#       : 山下智久勒
#      </span>
#      <span class="push-ipdatetime">
#       27.242.168.105 11/28 16:51
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       QVQ9487
#      </span>
#      <span class="f3 push-content">
#       : 沒阿部失敗
#      </span>
#      <span class="push-ipdatetime">
#       27.246.39.138 11/28 18:12
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       willy60109
#      </span>
#      <span class="f3 push-content">
#       : 喜歡阿部寬+1
#      </span>
#      <span class="push-ipdatetime">
#       39.10.126.172 11/28 19:39
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       噓
#      </span>
#      <span class="f3 hl push-userid">
#       jarvis652
#      </span>
#      <span class="f3 push-content">
#       : 沒山下智久？
#      </span>
#      <span class="push-ipdatetime">
#       1.165.119.170 11/28 21:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       m24523226
#      </span>
#      <span class="f3 push-content">
#       : 最愛西島爸爸 第一名只有我不解嗎？
#      </span>
#      <span class="push-ipdatetime">
#       118.168.58.171 11/28 22:28
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sekai
#      </span>
#      <span class="f3 push-content">
#       : 稻葉是不是因為都不會變老所以第一名
#      </span>
#      <span class="push-ipdatetime">
#       1.162.106.172 11/29 00:01
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       demon159000
#      </span>
#      <span class="f3 push-content">
#       : 阿嘶 都好帥
#      </span>
#      <span class="push-ipdatetime">
#       223.141.81.179 11/29 00:41
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wer90156
#      </span>
#      <span class="f3 push-content">
#       : 我大福山呢
#      </span>
#      <span class="push-ipdatetime">
#       180.204.44.103 11/29 03:03
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Dazzium
#      </span>
#      <span class="f3 push-content">
#       : 2.4.7很帥
#      </span>
#      <span class="push-ipdatetime">
#       223.137.110.217 11/29 08:30
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       edwardtp
#      </span>
#      <span class="f3 push-content">
#       : 沒福士覺得意外＋1
#      </span>
#      <span class="push-ipdatetime">
#       223.136.168.215 11/29 10:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Plasticine
#      </span>
#      <span class="f3 push-content">
#       : 我金城武沒有必要變別人
#      </span>
#      <span class="push-ipdatetime">
#       42.76.164.189 11/29 11:36
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       giantwinter
#      </span>
#      <span class="f3 push-content">
#       : B'z
#      </span>
#      <span class="push-ipdatetime">
#       42.73.26.243 11/29 17:34
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       sunwill34243
#      </span>
#      <span class="f3 push-content">
#       : 稻葉!!
#      </span>
#      <span class="push-ipdatetime">
#       111.184.227.178 11/29 20:06
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       yeeting
#      </span>
#      <span class="f3 push-content">
#       : 斗真呢?????智久呢??????????
#      </span>
#      <span class="push-ipdatetime">
#       124.12.51.251 11/30 02:20
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       tsunana2727
#      </span>
#      <span class="f3 push-content">
#       : 福士蒼汰 坂口健太郎 山下智久呢！
#      </span>
#      <span class="push-ipdatetime">
#       49.219.147.23 11/30 03:40
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       r10896
#      </span>
#      <span class="f3 push-content">
#       : 小田切讓呢
#      </span>
#      <span class="push-ipdatetime">
#       122.121.99.253 11/30 08:46
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Alexiel
#      </span>
#      <span class="f3 push-content">
#       : 沒有傑尼斯就100分
#      </span>
#      <span class="push-ipdatetime">
#       36.236.28.239 12/01 11:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       Alexiel
#      </span>
#      <span class="f3 push-content">
#       : 齋藤工蠻帥的,那個身材不輸歐美明星
#      </span>
#      <span class="push-ipdatetime">
#       36.236.28.239 12/01 11:58
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       natsu
#      </span>
#      <span class="f3 push-content">
#       : 推\吉沢亮/
#      </span>
#      <span class="push-ipdatetime">
#       106.107.176.208 12/01 13:31
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       MBAR
#      </span>
#      <span class="f3 push-content">
#       : 日本人審美真的很謎
#      </span>
#      <span class="push-ipdatetime">
#       180.217.133.189 12/01 15:32
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       wave7410
#      </span>
#      <span class="f3 push-content">
#       : 小栗旬呢
#      </span>
#      <span class="push-ipdatetime">
#       27.52.141.176 12/01 16:15
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cress0128
#      </span>
#      <span class="f3 push-content">
#       : 在日本不認識B'z的人會被排擠吧
#      </span>
#      <span class="push-ipdatetime">
#       140.115.110.134 12/03 17:49
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       angel801109
#      </span>
#      <span class="f3 push-content">
#       : 藤岡靛
#      </span>
#      <span class="push-ipdatetime">
#       111.83.239.124 12/03 21:52
#      </span>
#     </div>
#    </div>
#    <div data-longpollurl="/v1/longpoll?id=a091a41d4a0edab4937ff3bd471ee0adf68b652f" data-offset="15138" data-pollurl="/poll/Beauty/M.1574854555.A.E5C.html?cacheKey=2084-636623872&amp;offset=15138&amp;offset-sig=ae30ebb1e8bb5f33ef31998332706cfda3c15a6a" id="article-polling">
#    </div>
#    <div class="bbs-screen bbs-footer-message">
#     本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#  </body>
# </html>

# %%
# 決定要儲存的資料夾
output_dir = 'downloads'

# 假如資料夾不存在就新增一個資料夾
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 定位所有圖片的 tag
image_tags = soup.find(id='main-content').findChildren('a', recursive=False)
for img_tag in image_tags:
    # 取得所有圖片在第三方服務的 id
    if 'imgur' not in img_tag['href']:
        continue
    img_id = img_tag['href'].split('/')[-1]
    # 組合圖片而非網站的網址
    img_url = 'https://i.imgur.com/{}.jpg'.format(img_id)
    # 對圖片送出請求
    with requests.get(img_url, stream=True) as r:
        r.raise_for_status()
        # 檢查圖片副檔名
        img = Image.open(r.raw)
        img_savename = '{outdir}/{img_id}.{img_ext}'.format(
            outdir=output_dir, img_id=img_id, img_ext=img.format.lower())
        img.save(img_savename)
        print('Save image {}'.format(img_savename))
# Out:
# Save image downloads/Yvqa9MC.jpg.jpeg
# Save image downloads/4aqPUFf.jpg.jpeg
# Save image downloads/hG9seBk.jpg.jpeg
# Save image downloads/2M5b3z4.jpg.jpeg
# Save image downloads/ncyh1pY.jpg.jpeg
# Save image downloads/Z8L1vqU.jpg.jpeg
# Save image downloads/tJyl8gf.jpg.jpeg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ebb96c0e20fa> in <module>
#      22         img_savename = '{outdir}/{img_id}.{img_ext}'.format(
#      23             outdir=output_dir, img_id=img_id, img_ext=img.format.lower())
# ---> 24         img.save(img_savename)
#      25         print('Save image {}'.format(img_savename))
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2079                 fp = builtins.open(filename, "r+b")
#    2080             else:
# -> 2081                 fp = builtins.open(filename, "w+b")
#    2082
#    2083         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'downloads/hwry1vC.jpg.jpeg'
